# %%
#function for data processsing
def find_min(data):
    minimum = min(data)
    return minimum

numbers = [85, 90, 78, 92, 88, 94]
result = find_min(numbers)
print("Minimum Number:", result)


# Function to calculate sum
def calculate_sum(data):
    total = sum(data)
    return total
# Function to calculate average
def calculate_average(data):
    average = sum(data) / len(data)
    return average
# Using the functions
total = calculate_sum(numbers)
avg = calculate_average(numbers)

print("Total:", total)
print("Average:", avg)
# Out:
# Minimum Number: 78
# Total: 527
# Average: 87.83333333333333
